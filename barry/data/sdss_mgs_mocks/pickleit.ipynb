# %%
import pickle
import pandas as pd
import numpy as np
import os
d = "raw/"
files = sorted([d + f for f in os.listdir(d) if f.endswith("lpow")])
print(files)
# Out:
# ['raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9001_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9001_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9002_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9002_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9003_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9003_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9004_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9004_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9005_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9005_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9006_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9006_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9007_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9007_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9008_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9008_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9009_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9009_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9010_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9010_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9011_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9011_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9012_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9012_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9013_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9013_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9014_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9014_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9015_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9015_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9016_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9016_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9017_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9017_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9018_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9018_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9019_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9019_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9020_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9020_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9021_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9021_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9022_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9022_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9023_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9023_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9024_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9024_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9025_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9025_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9026_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9026_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9027_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9027_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9028_flip_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9028_v3.0_n200rand.lpow', 'raw/mock_gsafe0DR7VACNGCm_abM21.2_gr8.0_R9029_flip ...

# %%
def getdf(loc):
    df = pd.read_csv(loc, comment="#", delim_whitespace=True, names=["i", "k", "pk", "nk"])
    mask = df["nk"] > 0
    masked = df.loc[mask, ["k", "pk", "nk"]]
    return masked.astype(np.float32)

res = {f.lower(): getdf(f) for f in files}
split = {
    "pre-recon": [v for k, v in res.items() if "recon" not in k],
    "post-recon": [v for k, v in res.items() if "recon" in k]
}

# %%
with open("mock_lpow.pkl", "wb") as f:
    pickle.dump(split, f)

# %%
a = split["pre-recon"][0]

# %%
a
# Out:
#             k            pk        nk
# 0    0.000804  -1986.780029       1.0
# 1    0.002413   3794.850098       5.0
# 2    0.004021  10982.599609       8.0
# 3    0.005630  19650.099609       9.0
# 4    0.007238  31450.199219      28.0
# 5    0.008847  45883.699219      25.0
# 6    0.010455  56443.300781      32.0
# 7    0.012064  66648.398438      45.0
# 8    0.013672  77575.898438     100.0
# 9    0.015281  74963.500000      85.0
# 10   0.016889  77992.000000      80.0
# 11   0.018498  72039.601562     117.0
# 12   0.020106  69062.296875     152.0
# 13   0.021715  60528.101562     169.0
# 14   0.023323  51651.000000     168.0
# 15   0.024932  46852.101562     245.0
# 16   0.026540  42555.000000     240.0
# 17   0.028149  37703.500000     241.0
# 18   0.029757  41781.699219     340.0
# 19   0.031366  45900.500000     305.0
# 20   0.032974  45888.601562     376.0
# 21   0.034583  48829.500000     445.0
# 22   0.036191  50537.101562     432.0
# 23   0.037800  47445.898438     497.0
# 24   0.039408  41318.101562     476.0
# 25   0.041017  39218.601562     577.0
# 26   0.042625  35793.500000     632.0
# 27   0.044234  32619.900391     645.0
# 28   0.045842  29352.500000     672.0
# 29   0.047451  28387.099609     829.0
# ..        ...           ...       ...
# 469  0.755189    659.723999  186044.0
# 470  0.756797    645.671021  187881.0
# 471  0.758406    635.151978  187568.0
# 472  0.760014    636.515015  189877.0
# 473  0.761623    619.489014  186968.0
# 474  0.763231    611.541016  190269.0
# 475  0.764840    610.578979  190784.0
# 476  0.766448    623.281006  192285.0
# 477  0.768057    623.405029  192884.0
# 478  0.769665    635.283020  193429.0
# 479  0.771274    649.460022  194636.0
# 480  0.772882    640.075012  194421.0
# 481  0.774491    643.393005  196764.0
# 482  0.776099    628.960999  196505.0
# 483  0.777708    621.015015  196120.0
# 484  0.779316    616.612976  200797.0
# 485  0.780925    604.200989  198068.0
# 486  0.782533    609.945007  200057.0
# 487  0.784142    607.620972  200488.0
# 488  0.785750    603.908997  201865.0
# 489  0.787359    612.723022  202420.0
# 490  0.788967    616.674011  203881.0
# 491  0.790576    621.919983  203644.0
# 492  0.792184    612.465027  204325.0
# 493  0.793792    611.346985  206756.0
# 494  0.795401    592.336975  206253.0
# 495  0.797009    593.867981  207300.0
# 496  0.798618    582.864014  208189.0
# 497  0.800226    585.968018  209764.0
# 498  0.801835    568.544983  211513.0
#
# [499 rows x 3 columns]
