# %%
import pickle
import pandas as pd
import os
files = sorted([f for f in os.listdir() if f.endswith("lpow")])

# %%
result = {"pre-recon": [
    pd.read_csv(f, comment="#", delim_whitespace=True, 
                names=["i", "k", "pk", "nk"]) for f in files]}

# %%
with open("sdss_ms_mock_lpow.pkl", "wb") as f:
    pickle.dump(result, f)
